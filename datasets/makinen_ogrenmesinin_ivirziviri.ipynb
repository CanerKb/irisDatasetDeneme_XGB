# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data= pd.read_csv("data_with_nans.csv")

# %%
data.head()
# Out:
#    Unnamed: 0  Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0           0   0            5.1           3.5            1.4           0.2
# 1           1   1            4.7           3.2            1.6           0.2
# 2           2   2            4.9           3.1            1.5           0.1
# 3           3   3            4.4           2.9            1.4           0.2
# 4           4   4            5.0           3.4            1.5           0.2
#
#        Species
# 0  Iris-setosa
# 1  Iris-setosa
# 2  Iris-setosa
# 3  Iris-setosa
# 4  Iris-setosa

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 170 entries, 0 to 169
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     170 non-null    int64
#  1   Id             170 non-null    int64
#  2   SepalLengthCm  167 non-null    float64
#  3   SepalWidthCm   169 non-null    float64
#  4   PetalLengthCm  166 non-null    float64
#  5   PetalWidthCm   168 non-null    float64
#  6   Species        170 non-null    object
# dtypes: float64(4), int64(2), object(1)
# memory usage: 9.4+ KB

# %%
data.groupby(by="Species").agg(["min", "max", "mean", "std"])
# Out:
#                 Unnamed: 0                          Id                         \
#                        min  max   mean        std  min  max   mean        std
# Species
# Iris-setosa              0   59   29.5  17.464249    0   59   29.5  17.464249
# Iris-versicolor         60  113   86.5  15.732133   60  113   86.5  15.732133
# Iris-virginica         114  169  141.5  16.309506  114  169  141.5  16.309506
#
#                 SepalLengthCm       ... SepalWidthCm           PetalLengthCm  \
#                           min  max  ...         mean       std           min
# Species                             ...
# Iris-setosa               4.3  6.9  ...     3.389831  0.390709           1.0
# Iris-versicolor           4.9  7.0  ...     2.805556  0.382355           1.5
# Iris-virginica            4.9  7.9  ...     2.996429  0.355203           1.3
#
#                                          PetalWidthCm
#                  max      mean       std          min  max      mean       std
# ...

# %%
data.describe().T
# Out:
#                count       mean        std  min    25%   50%     75%    max
# Unnamed: 0     170.0  84.500000  49.218899  0.0  42.25  84.5  126.75  169.0
# Id             170.0  84.500000  49.218899  0.0  42.25  84.5  126.75  169.0
# SepalLengthCm  167.0   5.826347   0.827189  4.3   5.10   5.8    6.40    7.9
# SepalWidthCm   169.0   3.072781   0.447578  2.0   2.80   3.0    3.40    4.4
# PetalLengthCm  166.0   3.707229   1.789382  1.0   1.50   4.3    5.10    6.9
# PetalWidthCm   168.0   1.180357   0.765049  0.1   0.30   1.3    1.80    2.5

# %%
data.drop(labels=["Unnamed: 0"], inplace= True , axis= 1 )

# %%
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   0            5.1           3.5            1.4           0.2  Iris-setosa
# 1   1            4.7           3.2            1.6           0.2  Iris-setosa
# 2   2            4.9           3.1            1.5           0.1  Iris-setosa
# 3   3            4.4           2.9            1.4           0.2  Iris-setosa
# 4   4            5.0           3.4            1.5           0.2  Iris-setosa

# %%
data.isna().sum()
# Out:
# Id               0
# SepalLengthCm    3
# SepalWidthCm     1
# PetalLengthCm    4
# PetalWidthCm     2
# Species          0
# dtype: int64

# %%
data.dropna(axis=0 , how="any", inplace= True)

# %%
data.isna().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 160 entries, 0 to 169
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             160 non-null    int64
#  1   SepalLengthCm  160 non-null    float64
#  2   SepalWidthCm   160 non-null    float64
#  3   PetalLengthCm  160 non-null    float64
#  4   PetalWidthCm   160 non-null    float64
#  5   Species        160 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 8.8+ KB

# %%
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   0            5.1           3.5            1.4           0.2  Iris-setosa
# 1   1            4.7           3.2            1.6           0.2  Iris-setosa
# 2   2            4.9           3.1            1.5           0.1  Iris-setosa
# 3   3            4.4           2.9            1.4           0.2  Iris-setosa
# 4   4            5.0           3.4            1.5           0.2  Iris-setosa

# %%
sns.pairplot(data=data, hue= "Species");

# %%
sns.scatterplot(data= data, x="SepalLengthCm", y="Id", hue= "Species");

# %%
sns.set_style("dark")
sns.set(rc={"figure.figsize": (14,8)}) # bundan sonraki tüm grafikler 14 : 8 ebatlarında olacak!
sns.scatterplot(data= data, x="SepalLengthCm", y="Id", hue= "Species", palette="gist_heat" , sizes=2);

# %%
# fig, ax = plt.subplots()

# %%
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   0            5.1           3.5            1.4           0.2  Iris-setosa
# 1   1            4.7           3.2            1.6           0.2  Iris-setosa
# 2   2            4.9           3.1            1.5           0.1  Iris-setosa
# 3   3            4.4           2.9            1.4           0.2  Iris-setosa
# 4   4            5.0           3.4            1.5           0.2  Iris-setosa

# %%
fig, ax = plt.subplots()

# %%
data_1= data.groupby(by="Species").mean()["SepalLengthCm"]
data_1
# Out:
# Species
# Iris-setosa        5.048148
# Iris-versicolor    5.921569
# Iris-virginica     6.560000
# Name: SepalLengthCm, dtype: float64

# %%
ax= sns.barplot(x= data_1.index, y=data_1.values)
ax.set_title("Sepal Length(cm) Mean ")
ax.set_ylabel("Mean")
# Out:
# Text(0, 0.5, 'Mean')

# %%
data_3= data.groupby(by="Species").mean()
data_3
# Out:
#                          Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Species
# Iris-setosa       26.870370       5.048148      3.398148       1.587037
# Iris-versicolor   85.313725       5.921569      2.792157       4.184314
# Iris-virginica   141.163636       6.560000      3.000000       5.476364
#
#                  PetalWidthCm
# Species
# Iris-setosa          0.301852
# Iris-versicolor      1.303922
# Iris-virginica       1.992727

# %%
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   0            5.1           3.5            1.4           0.2  Iris-setosa
# 1   1            4.7           3.2            1.6           0.2  Iris-setosa
# 2   2            4.9           3.1            1.5           0.1  Iris-setosa
# 3   3            4.4           2.9            1.4           0.2  Iris-setosa
# 4   4            5.0           3.4            1.5           0.2  Iris-setosa

# %%
data.iloc[:,1:-1]
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0              5.1           3.5            1.4           0.2
# 1              4.7           3.2            1.6           0.2
# 2              4.9           3.1            1.5           0.1
# 3              4.4           2.9            1.4           0.2
# 4              5.0           3.4            1.5           0.2
# ..             ...           ...            ...           ...
# 165            5.7           2.5            5.0           2.0
# 166            6.8           3.0            5.5           2.1
# 167            6.4           2.7            5.3           1.9
# 168            7.2           3.6            6.1           2.5
# 169            6.3           3.3            6.0           2.5
#
# [160 rows x 4 columns]

# %%
for column in data.iloc[:,1:-1]:
    
    print(column)
# Out:
# SepalLengthCm
# SepalWidthCm
# PetalLengthCm
# PetalWidthCm

# %%
ax= sns.barplot(x= data_3.index, y=data_3.values)
ax.set_title("Sepal Length(cm) Mean")
ax.set_ylabel("Mean")
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-98-b81a920f707d> in <module>
# ----> 1 ax= sns.barplot(x= data_3.index, y=data_3.values)
#       2 ax.set_title("Sepal Length(cm) Mean")
#       3 ax.set_ylabel("Mean")
#
# C:\Anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# C:\Anaconda3\lib\site-packages\seaborn\categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3167 ):
#    3168
# -> 3169     plotter = _BarPlotter(x, y, hue, data, order, hue_order,
# ...
